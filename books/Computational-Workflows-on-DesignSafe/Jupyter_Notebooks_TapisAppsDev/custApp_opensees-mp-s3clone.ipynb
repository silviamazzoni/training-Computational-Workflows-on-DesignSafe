# %% [markdown]
# <a class="reference external" href="https://jupyter.designsafe-ci.org/hub/user-redirect/lab/tree/CommunityData/Training/Computational-Workflows-on-DesignSafe/Jupyter_Notebooks/Jupyter_Notebooks_TapisAppsDev/custApp_opensees-mp-s3clone.ipynb" target="_blank">
# <img alt="Try on DesignSafe" src="https://raw.githubusercontent.com/DesignSafe-Training/pinn/main/DesignSafe-Badge.svg" /></a>

# %% [markdown]
# # Custom App: opensees-mp-s3-clone
# ***Create your own Tapis App: duplicate opensees-mp-s3 app***
#
# by Silvia Mazzoni, DesignSafe, 2025
#
# This is a step-by-step guide to help you write your own **Tapis v3 App** — from defining the app, to registering it, and running it.
#
# This is a practical walkthrough for defining and deploying an **HPC** app using the Tapis v3 API.
#
# As the very first step in writing your own app, we will replicate the opensees-mp-s3 app verbatim
#
# ## App-Creation Workflow
#
# | Step                        | Description                                                         |
# | --------------------------- | ------------------------------------------------------------------- |
# | 1. Create *app.json*        | Describes the app, its inputs, execution system, and wrapper script |
# | 2. Create *tapisjob_app.sh* | Runs your analysis (e.g., ibrun OpenSees main.tcl)                  |
# | 3. Create *profile.json*    | (Optional) Loads modules/environment                                |
# | 4. Upload Files             | To the deployment path in your storage system                       |
# | 5. Register App             | With Tapis via CLI or Python                                        |
# | 6. Submit Job               | Define `job.json` and submit                                        |

# %%
# Import Utilities Library
import os,sys
PathOpsUtils = os.path.expanduser('~/CommunityData/Training/Computational-Workflows-on-DesignSafe/OpsUtils')
if not PathOpsUtils in sys.path: sys.path.append(PathOpsUtils)
from OpsUtils import OpsUtils

# %%
import json

# %%
# Make these True once you are done validating
do_makeAppFiles = True
do_upload = True
do_register = True
do_submitJob = True

# %% [markdown]
# ---
# ## Connect to Tapis

# %%
t=OpsUtils.connect_tapis()
# Out:
#  -- Checking Tapis token --
#  Token loaded from file. Token is still valid!
#  Token expires at: 2026-02-10T21:07:10+00:00
#  Token expires in: 3:49:51.899299
# -- AUTHENTICATED VIA SAVED TOKEN --

# %% [markdown]
# ---
# ## Configure App

# %%
app_id = 'opensees-mp-s3-clone'
# app_version = '0.0.3'

# %% [markdown]
# ### Autoincrement version

# %%
if do_makeAppFiles or do_upload or do_register:
    app_version = OpsUtils.increment_tapis_app_version(t,app_id)
# Out:
# new app
# now app_version 0.0.1

# %% [markdown]
# ### Define folder structure: app_id/version

# %%
app_folderName = f'~/MyData/myAuthoredTapisApps/{app_id}/{app_version}'; # your choice

# %%
app_folder = os.path.abspath(os.path.expanduser(app_folderName))
os.makedirs(app_folder, exist_ok=True)
print(f'app_folder: {app_folder}\n exists:',os.path.exists(app_folder))
# Out:
# app_folder: /home/jupyter/MyData/myAuthoredTapisApps/opensees-mp-s3-clone/0.0.1
#  exists: True

# %% [markdown]
# ---
# ## Create the App Files
#
# A Tapis app needs the following **core files**:
#
# We will be creating an app that runs an OpenSeesMP simulation on Stampede3. This app is an identical copy to **opensees-mp-s3** on DesignSafe --
# [Template in GitHub](https://github.com/TACC/WMA-Tapis-Templates/tree/main/applications/opensees-mp/opensees-mp-s3)
#
# * **Readme.MD** – App Description (OPTIONAL)<br>
# This file is helpful in communicating content to the app user.
#
# * **app.json** – App Definition<br>
# Defines the app’s metadata, inputs, parameters, and execution configuration.
#
# * **profile.json** – Environment Setup *(optional but common)*<br>
# Loads modules or sets environment variables on the execution system. This file will load modules before your script runs. This is executed on the compute node.
#
# * **tapisjob_app.sh** – Wrapper Script<br>
# Wrapper script executed by the job; this is the command that launches your code (e.g., runs *OpenSeesMP*, Python, or a script)

# %%
# let's collect the list of files we are creating as we will need this list in upload
appFilesList = [];

# %% [markdown]
# #### **Readme.MD** – App Description
# This file is helpful in communicating content to the app user.

# %%
thisFilename = 'ReadMe.MD'
if do_makeAppFiles:
    thisText = """\
    # OpenSees-MP Stampede3 version Latest -- copy Silvia
    
    This app uses opensees tacc module with tapis zip runtime.
    Just testing the original app with no modifications
    """
    
    with open(f"{app_folder}/{thisFilename}", "w") as f:
        f.write(thisText)

appFilesList.append(thisFilename)

# %% [markdown]
# #### **app.json** – App Definition
# Defines the app’s metadata, inputs, parameters, and execution configuration.

# %%
thisFilename = 'app.json'
if do_makeAppFiles:
    thisText = """\
    {
      "id": "__app_id__",
      "version": "__app_version__",
      "description": "Runs all the processors in parallel. Requires understanding of parallel processing and the capabilities to write parallel scripts.",
      "owner": "${apiUserId}",
      "enabled": true,
      "runtime": "ZIP",
      "runtimeVersion": null,
      "runtimeOptions": null,
      "containerImage": "tapis://cloud.data/corral/tacc/aci/CEP/applications/v3/opensees/latest/OpenSees/opensees.zip",
      "jobType": "BATCH",
      "maxJobs": -1,
      "maxJobsPerUser": -1,
      "strictFileInputs": true,
      "jobAttributes": {
        "execSystemConstraints": null,
        "execSystemId": "stampede3",
        "execSystemExecDir": "${JobWorkingDir}",
        "execSystemInputDir": "${JobWorkingDir}",
        "execSystemOutputDir": "${JobWorkingDir}",
        "execSystemLogicalQueue": "skx",
        "archiveSystemId": "stampede3",
        "archiveSystemDir": "HOST_EVAL($WORK)/tapis-jobs-archive/${JobCreateDate}/${JobName}-${JobUUID}",
        "archiveOnAppError": true,
        "isMpi": false,
        "mpiCmd": null,
        "parameterSet": {
          "appArgs": [
            {
              "name": "Main Program",
              "arg": "OpenSeesMP",
              "inputMode": "FIXED",
              "notes": {
                "isHidden": true
              }
            },
            {
              "name": "Main Script",
              "description": "The filename only of the OpenSees TCL script to execute. This file should reside in the Input Directory specified. To use with test input, use 'freeFieldEffective.tcl'",
              "arg": null,
              "inputMode": "REQUIRED",
              "notes": {
                "inputType": "fileInput"
              }
            }
          ],
          "containerArgs": [],
          "schedulerOptions": [
            {
              "name": "OpenSees TACC Scheduler Profile",
              "description": "Scheduler profile for the default version of OpenSees",
              "inputMode": "FIXED",
              "arg": "--tapis-profile OpenSees_default",
              "notes": {
                "isHidden": true
              }
            }
          ],
          "envVariables": [],
          "archiveFilter": {
            "includes": [],
            "excludes": [],
            "includeLaunchFiles": true
          }
        },
        "fileInputs": [
          {
            "name": "Input Directory",
            "inputMode": "REQUIRED",
            "sourceUrl": null,
            "targetPath": "inputDirectory",
            "envKey": "inputDirectory",
            "description": "Input directory that includes the tcl script as well as any other required files. Example input is in tapis://designsafe.storage.community/app_examples/opensees/OpenSeesMP",
            "notes": {
              "selectionMode": "directory"
            }
          }
        ],
        "fileInputArrays": [],
        "nodeCount": 2,
        "coresPerNode": 48,
        "memoryMB": 192000,
        "maxMinutes": 120,
        "subscriptions": [],
        "tags": []
      },
      "tags": [
        "portalName: DesignSafe",
        "portalName: CEP"
      ],
      "notes": {
        "label": "OpenSeesMP",
        "helpUrl": "https://www.designsafe-ci.org/user-guide/tools/simulation/#opensees-user-guide",
        "hideNodeCountAndCoresPerNode": false,
        "isInteractive": false,
        "icon": "OpenSees",
        "category": "Simulation"
      }
    }
    """
    thisText = thisText.replace("__app_id__", app_id)
    thisText = thisText.replace("__app_version__", app_version)
    
    with open(f"{app_folder}/{thisFilename}", "w") as f:
        f.write(thisText)

appFilesList.append(thisFilename)

# %% [markdown]
# #### **profile.json** – Environment Setup
# This file will load modules before your script runs. This is executed on the compute node.

# %%
thisFilename = 'profile.json'
if do_makeAppFiles:
    thisText = """\
    {
        "name": "OpenSees_default",
        "description": "Modules to load for the default version of OpenSees",
        "moduleLoads": [
            {
                "modulesToLoad": [
                    "hdf5/1.14.4",
                    "opensees"
                ],
                "moduleLoadCommand": "module load"
            }
        ],
        "hiddenOptions": [
            "MEM"
        ]
    }
    """
    
    with open(f"{app_folder}/{thisFilename}", "w") as f:
        f.write(thisText)

appFilesList.append(thisFilename)

# %% [markdown]
# #### **tapisjob_app.sh** – Wrapper Script
# Wrapper script executed by the job; this is the command that launches your code (e.g., runs *OpenSeesMP*, Python, or a script)

# %%
thisFilename = 'tapisjob_app.sh'
if do_makeAppFiles:
    thisText = """\
    set -x
    
    BINARYNAME=$1
    INPUTSCRIPT=$2
    echo "INPUTSCRIPT is $INPUTSCRIPT"
    
    TCLSCRIPT="${INPUTSCRIPT##*/}"
    echo "TCLSCRIPT is $TCLSCRIPT"
    
    cd "${inputDirectory}"
    
    echo "Running $BINARYNAME"
    
    ibrun $BINARYNAME $TCLSCRIPT
    if [ ! $? ]; then
          echo "OpenSees exited with an error status. $?" >&2
          exit
    fi
    
    cd ..
    """

    with open(f"{app_folder}/{thisFilename}", "w") as f:
        f.write(thisText)

appFilesList.append(thisFilename)

# %% [markdown]
# #### File Check
# Look at the files we have written and check for typos or formatting errors.

# %%
print(appFilesList)
OpsUtils.show_text_file_in_accordion(app_folder, appFilesList)
# Out:
# ['ReadMe.MD', 'app.json', 'profile.json', 'tapisjob_app.sh']
# Output()

# %% [markdown]
# ---
# ## Validate App Locally

# %%
OpsUtils.show_text_file_in_accordion(PathOpsUtils, ['validate_app_folder.py'])
# Out:
# Output()

# %%
# Run validation
validation = OpsUtils.validate_app_folder(app_folder,appFilesList)
if not validation:
    print('Validation Failed: stopping here!!!!')
    a = 3/0
# Out:
# 🔍 Validating app folder: /home/jupyter/MyData/myAuthoredTapisApps/opensees-mp-s3-clone/0.0.1
#
# ✅ All required files are present.
#
# 📄 App ID: opensees-mp-s3-clone
# 📄 App Name: OpenSees_default
# 📄 Version: 0.0.1
# 🔧 Parameters: []
# 📦 Inputs: []
# 📤 Outputs: []
#
# App Keys: ['id', 'version', 'description', 'owner', 'enabled', 'runtime', 'runtimeVersion', 'runtimeOptions', 'containerImage', 'jobType', 'maxJobs', 'maxJobsPerUser', 'strictFileInputs', 'jobAttributes', 'tags', 'notes', 'name', 'moduleLoads', 'hiddenOptions']
#
# ✅ Basic validation complete. App folder looks good!

# %% [markdown]
# ---
# ## Deploy the App

# %% [markdown]
# ### Get username

# %%
OpsUtils.show_text_file_in_accordion(PathOpsUtils, ['get_tapis_username.py'])
# Out:
# Output()

# %%
username = OpsUtils.get_tapis_username(t)
print('username',username)
# Out:
# username silvia

# %% [markdown]
# ### Make the directory inside your 'MyData' on designsafe.storage.default.
# The apps in this folder are the ones that area actually uploaded.

# %%
if do_upload:
    app_system_id="designsafe.storage.default"
    app_path = f"{username}/apps/{app_id}/{app_version}"
    t.files.mkdir(systemId=app_system_id, path=app_path)
    print('app_path',app_path)
# Out:
# app_path silvia/apps/opensees-mp-s3-clone/0.0.1

# %% [markdown]
# ### Upload files to your deployment system (e.g., DesignSafe default storage)
# Using Tapipy (Python SDK) in a Jupyter Notebook

# %%
if do_upload:
    for fname in appFilesList:
        fpath = f'{app_folder}/{fname}'
        t.upload(source_file_path=fpath,
                 system_id=app_system_id,
                 dest_file_path=f'{app_path}/{fname}')

# %% [markdown]
# #### Verify upload

# %%
if do_upload:
    print('app_system_id:',app_system_id)
    print('app_path:',app_path)
    t.files.listFiles(systemId=app_system_id, path=app_path)
# Out:
# app_system_id: designsafe.storage.default
# app_path: silvia/apps/opensees-mp-s3-clone/0.0.1

# %% [markdown]
# ---
# ## Register the App
# This creates the actual App record that Jobs can run.
#
# Do this Using Tapipy (Python)

# %%
if do_register:
    # Create (or create a new version) of the app
    with open(f'{app_folder}/app.json') as f:
        app_def = json.load(f)
    t.apps.createAppVersion(**app_def)

# %% [markdown]
# ### Check that app is up

# %% [markdown]
# #### List all apps

# %%
if do_register:
    listType = 'ALL' # Include all items requester is authorized to view. Includes check for READ or MODIFY permission.
    select = 'id,created,description,version,owner' # Attributes to return in each result.
    orderBy = 'created(asc)'
    results = t.apps.getApps( orderBy=orderBy,
                             select=select)  
    for thisRes in results:
        print('--')
        print(thisRes)
# Out:
# --
#
# created: 2024-12-13T20:15:33.014747Z
# description: Run shell commands on remote systems
# id: shell-runner-1.0.0
# owner: silvia
# version: 1.0.0
# --
#
# created: 2024-12-14T15:49:21.510206Z
# description: Run shell commands on remote systems
# id: shell-runner
# owner: silvia
# version: 1.0.0
# --
#
# created: 2025-08-16T16:51:35.355715Z
# description: Runs all the processors in parallel. Requires understanding of parallel processing and the capabilities to write parallel scripts.
# id: opensees-mp-s3-silvia
# owner: silvia
# version: latest
# --
#
# created: 2025-08-16T18:53:58.422294Z
# description: Runs all the processors in parallel. Requires understanding of parallel processing and the capabilities to write parallel scripts.
# id: opensees-mp-s3-silvia-new
# owner: silvia
# version: latest
# --
#
# created: 2025-08-17T22:34:01.193589Z
# description: Runs all the processors in parallel. Requires understanding of parallel processing and the capabilities to write parallel scripts.
# id: opensees-mp-s3-copy-silvia
# owner: silvia
# version: 0.0.2
# --
#
# created: 2026-01-14T06:00:53.368344Z
# description: Runs all the processors in parallel. Requires understanding of parallel processing and the capabilities to write parallel scripts.
# id: opensees-mp-s3-copy-mine
# owner: silvia
# version: 0.0.19
# --
#
# created: 2025-08-18T02:18:22.973797Z
# description: Run either OpenSeesSP or OpenSeesMP
# id: opensees-tcl-mine
# owner: silvia
# version: 0.0.1
# --
#
# created: 2025-08-18T04:35:56.608017Z
# description: Run any OpenSees
# id: opensees-agnostic
# owner: silvia
# version: 0.0.5
# --
#
# created: 2025-08-18T06:19:28.859427Z
# description: Run any OpenSees
# id: opensees-agnostic2
# owner: silvia
# version: 0.0.3
# --
#
# created: 2025-11-20T03:26:38.676695Z
# description: Run anything
# id: agnostic-app-test
# owner: silvia
# version: 0.0.257
# --
#
# created: 2025-12-04T20:11:40.911154Z
# description: get work path
# id: get-work-path-test
# owner: silvia
# version: 0.0.17
# --
#
# created: 2026-01-14T15:12:20.018358Z
# description: Create Virtual Environment
# id: virtual-env-app-test
# owner: silvia
# version: 0.0.51
# --
#
# created: 2026-01-14T15:12:20.313582Z
# description: Validate a micromamba Python env (version, imports, optional MPI hello)
# id: virtual-env-app-test-tester
# owner: silvia
# version: 0.0.33
# --
#
# created: 2025-10-08T03:04:13.708018Z
# description: Run launcher on TACC
# id: launcher-test
# owner: silvia
# version: 0.0.5
# --
#
# created: 2026-01-14T15:17:17.036748Z
# description: Create Virtual Environment
# id: python-virtual-env
# owner: silvia
# version: 0.0.57
# --
#
# created: 2025-11-13T04:31:25.159621Z
# description: Runs all the processors in parallel. Requires understanding of parallel processing and the capabilities to write parallel scripts.
# id: opensees-mp-s3-copy-add-opsPy
# owner: silvia
# version: 0.0.11
# --
#
# created: 2026-01-14T16:00:54.128801Z
# description: Runs all the processors in parallel. Requires understanding of parallel processing and the capabilities to write parallel scripts.
# id: opensees-mp-s3-copy-add-opsPy-b
# owner: silvia
# version: 0.0.14
# --
#
# created: 2025-11-24T16:55:08.011698Z
# description: Agnostic Tapis App for OpenSees, OpenSeesMP, OpenSeesSP, OpenSeesPy, and General Python Execution
# id: agnostic-app
# owner: silvia
# version: 0.0.20
# --
#
# created: 2026-02-10T04:55:26.205371Z
# description: Agnostic Tapis App for General Python Execution as well as OpenSees, OpenSeesMP, OpenSeesSP, OpenSeesPy
# id: designsafe-agnostic-app
# owner: silvia
# version: 1.3.9
# --
#
# created: 2026-02-10T04:55:26.471373Z
# description: Basic App to run OpenSeesPy on stampede3.
# id: designsafe-openseespy-s3
# owner: silvia
# version: 1.2.13
# --
#
# created: 2026-01-14T19:29:10.530751Z
# description: Agnostic Tapis App for General Python Execution as well as OpenSees, OpenSeesMP, OpenSeesSP, OpenSeesPy
# id: demo-agnostic-app
# owner: silvia
# version: 0.0.4
# --
#
# created: 2026-01-14T19:29:10.813640Z
# description: Basic App to run OpenSeesPy on stampede3.
# id: demo-openseespy-s3
# owner: silvia
# version: 0.0.4
# --
#
# created: 2026-02-10T17:18:03.240586Z
# description: Runs all the processors in parallel. Requires understanding of parallel processing and the capabilities to write parallel scripts.
# id: opensees-mp-s3-clone
# owner: silvia
# version: 0.0.1

# %% [markdown]
# #### List the new app's schema

# %%
if do_register:
    appMetaData = t.apps.getAppLatestVersion(appId=app_def["id"])

    monitor_out = widgets.Output()
    monitor_accordion = widgets.Accordion(children=[monitor_out])
    monitor_accordion.selected_index = 0
    monitor_accordion.set_title(0, f'App Schema')
    display(monitor_accordion)
    
    with monitor_out:
        OpsUtils.display_tapis_app_schema(appMetaData)
# Out:
# Accordion(children=(Output(),), selected_index=0, titles=('App Schema',))

# %% [markdown]
# ## Submit a Job
#
# You can now submit a job using this app. You can use the Tapis CLI, Tapipy, or a web form.
#
# We are using TapiPy directly from this notebook. We will not specify a version so that the latest is used by default in the description.

# %%
print('app_id:',app_id)
# print('app_version:',app_version)
# Out:
# app_id: opensees-mp-s3-clone

# %% [markdown]
# ### App-Specific Input

# %%
# initalize
tapisInputAll = {}
tapisInputAll["name"] = 'SilviaApp_OpenSeesMPs3Copy'

tapisInputAll["appId"] = app_id # options: "opensees-express", "opensees-mp-s3", "opensees-2p-s3"
# tapisInputAll["appVersion"] = app_version # always use latest in this Notebook Template
tapisInputAll["maxMinutes"] = 6

# OpenSees-mp-s3 and OpenSees-xp-s3 only:
tapisInputAll["execSystemId"] = "stampede3" # the app runs on stampede only
tapisInputAll["execSystemLogicalQueue"] = "skx-dev" # "skx", "skx-dev"
tapisInputAll["nodeCount"] = 1 # limits set by which compute nodes you use
tapisInputAll["coresPerNode"] = 48 # limits set by which compute nodes you use
tapisInputAll["allocation"] = "DS-HPC1"

tapisInputAll['archive_system']='MyData' # Options: MyData or Work

# %% [markdown]
# ### Job-Specific Input

# %%
# initalize
tapisInput = tapisInputAll.copy()

tapisInput['storage_system'] = 'CommunityData'
tapisInput['input_folder'] = 'OpenSees/TrainingMaterial/training-OpenSees-on-DesignSafe/Examples_OpenSees/BasicExamples'

tapisInput["name"] = tapisInput["name"] + '_' + tapisInput['storage_system']

tapisInput['Main Script'] = 'Ex1a_verymany.Canti2D.Push.mp.tcl'

# %% [markdown]
# ### Submit

# %%
OpsUtils.show_text_file_in_accordion(PathOpsUtils, ['run_tapis_job.py'])
# Out:
# Output()

# %%
# -----------------------------------------------------
if do_submitJob:
    jobReturns = OpsUtils.run_tapis_job(t,tapisInput,get_job_metadata=True,get_job_history=True,get_job_filedata=True,askConfirmJob = False,askConfirmMonitorRT = False)
    print('JobStatusData:',jobReturns['JobStatusData'])
# -----------------------------------------------------
# Out:
# Accordion(children=(Output(),), selected_index=0, titles=('',))
# JobStatusData:
# condition: NORMAL_COMPLETION
# status: FINISHED

# %%
jobReturns
# Out:
# {'jobUuid': '41d6ee21-d6a4-4898-886b-8e99870bf854-007',
#  'submitted_job':
#  _fileInputsSpec: None
#  _parameterSetModel: None
#  appId: opensees-mp-s3-clone
#  appVersion: 0.0.1
#  archiveCorrelationId: None
#  archiveMode: ALWAYS
#  archiveOnAppError: True
#  archiveSystemDir: /silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007
#  archiveSystemId: designsafe.storage.default
#  archiveTransactionId: None
#  blockedCount: 0
#  cmdPrefix: None
#  condition: None
#  coresPerNode: 48
#  created: 2026-02-10T17:18:03.777231186Z
#  createdby: silvia
#  createdbyTenant: designsafe
#  description: opensees-mp-s3-clone-0.0.1 submitted by silvia@designsafe
#  dtnInputCorrelationId: None
#  dtnInputTransactionId: None
#  dtnOutputCorrelationId: None
#  dtnOutputTransactionId: None
#  dtnSystemId: None
#  dtnSystemInputDir: None
#  dtnSystemOutputDir: None
#  dynamicExecSystem: False
#  ended: None
#  execSystemConstraints: None
#  execSystemExecDir: /scratch/05072/silvia/tapis/41d6ee21-d6a4-4898-886b-8e99870bf854-007
#  execSystemId: stampede3
#  execSystemInputDir: /scratch/05072/silvia/tapis/41d6ee21-d6a4-4898-886b-8e99870bf854-007
#  execSystemLogicalQueue: skx-dev
#  execSystemOutputDir: /scratch/05072/silvia/tapis/41d6ee21-d6a4-4898-886b-8e99870bf854-007
#  fileInputs: [{"name":"Input Directory","description":"Input directory that includes the tcl script as well as any other required files. Example input is in tapis://designsafe.storage.community/app_examples/opensees/OpenSeesMP","envKey":"inputDirectory","autoMountLocal":true,"sourceUrl":"tapis://designsafe.storage.community/OpenSees/TrainingMaterial/training-OpenSees-on-DesignSafe/Examples_OpenSees/BasicExamples","targetPath":"inputDirectory","notes":"{\"selectionMode\":\"directory\"}","optional":false,"srcSharedAppCtx":"","destSharedAppCtx":"silvia"}]
#  id: 0
#  inputCorrelationId: None
#  inputTransactionId: None
#  isMpi: False
#  jobType: BATCH
#  lastMessage: Job created
#  lastUpdated: 2026-02-10T17:18:03.777231186Z
#  maxMinutes: 6
#  memoryMB: 192000
#  mpiCmd: None
#  name: SilviaApp_OpenSeesMPs3Copy_CommunityData
#  nodeCount: 1
#  notes:
#  category: Simulation
#  helpUrl: https://www.designsafe-ci.org/user-guide/tools/simulation/#opensees-user-guide
#  hideNodeCountAndCoresPerNode: False
#  icon: OpenSees
#  isInteractive: False
#  label: OpenSeesMP
#  owner: silvia
#  parameterSet: {"appArgs":[{"name":"Main Program","description":null,"include":null,"arg":"OpenSeesMP","notes":"{\"isHidden\":true}"},{"name":"Main Script","description":"The filename only of the OpenSees TCL script to execute. This file should reside in the Input Directory specified. To use with test input, use 'freeFieldEffective.tcl'","include":null,"arg":"Ex1a_verymany.Canti2D.Push.mp.tcl","notes":"{\"inputType\":\"fileInput\"}"}],"containerArgs":[],"schedulerOptions":[{"name":"OpenSees TACC Scheduler Profile","description":"Scheduler profile for the default version of OpenSees","include":null,"arg":"--tapis-profile OpenSees_default","notes":"{\"isHidden\":true}"},{"name":"TACC Allocation","description":null,"include":null,"arg":"-A DS-HPC1","notes":null}],"envVariables":[{"key":"_tapisAppId","value":"opensees-mp-s3-clone","description":null,"include":null,"notes":null},{"key":"_tapisAppVersion","value":"0.0.1","description":null,"include":null,"notes":null},{"key":"_tapisArchiveMode","value":"ALWAYS","description":null,"include":null,"notes":null},{"key":"_tapisArchiveOnAppError","value":"true","description":null,"include":null,"notes":null},{"key":"_tapisArchiveSystemDir","value":"/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007","description":null,"include":null,"notes":null},{"key":"_tapisArchiveSystemId","value":"designsafe.storage.default","description":null,"include":null,"notes":null},{"key":"_tapisCoresPerNode","value":"48","description":null,"include":null,"notes":null},{"key":"_tapisDynamicExecSystem","value":"false","description":null,"include":null,"notes":null},{"key":"_tapisEffectiveUserId","value":"silvia","description":null,"include":null,"notes":null},{"key":"_tapisExecSystemExecDir","value":"/scratch/05072/silvia/tapis/41d6ee21-d6a4-4898-886b-8e99870bf854-007","description":null,"include":null,"notes":null},{"key":"_tapisExecSystemHPCQueue","value":"skx-dev","description":null,"include":null,"notes":null},{"key":"_tapisExecSystemId","value":"stampede3","description":null,"include":null,"notes":null},{"key":"_tapisExecSystemInputDir","value":"/scratch/05072/silvia/tapis/41d6ee21-d6a4-4898-886b-8e99870bf854-007","description":null,"include":null,"notes":null},{"key":"_tapisExecSystemLogicalQueue","value":"skx-dev","description":null,"include":null,"notes":null},{"key":"_tapisExecSystemOutputDir","value":"/scratch/05072/silvia/tapis/41d6ee21-d6a4-4898-886b-8e99870bf854-007","description":null,"include":null,"notes":null},{"key":"_tapisJobCreateDate","value":"2026-02-10Z","description":null,"include":null,"notes":null},{"key":"_tapisJobCreateTime","value":"17:18:03.777231186Z","description":null,"include":null,"notes":null},{"key":"_tapisJobCreateTimestamp","value":"2026-02-10T17:18:03.777231186Z","description":null,"include":null,"notes":null},{"key":"_tapisJobName","value":"SilviaApp_OpenSeesMPs3Copy_CommunityData","description":null,"include":null,"notes":null},{"key":"_tapisJobOwner","value":"silvia","description":null,"include":null,"notes":null},{"key":"_tapisJobUUID","value":"41d6ee21-d6a4-4898-886b-8e99870bf854-007","description":null,"include":null,"notes":null},{"key":"_tapisJobWorkingDir","value":"/scratch/05072/silvia/tapis/41d6ee21-d6a4-4898-886b-8e99870bf854-007","description":null,"include":null,"notes":null},{"key":"_tapisMaxMinutes","value":"6","description":null,"include":null,"notes":null},{"key":"_tapisMemoryMB","value":"192000","description":null,"include":null,"notes":null},{"key":"_tapisNodes","value":"1","description":null,"include":null,"notes":null},{"key":"_tapisStderrFilename","value":"tapisjob.out","description":null,"include":null,"notes":null},{"key":"_tapisStdoutFilename","value":"tapisjob.out","description":null,"include":null,"notes":null},{"key":"_tapisSysBatchScheduler","value":"SLURM","description":null,"include":null,"notes":null},{"key":"_tapisSysHost","value":"stampede3.tacc.utexas.edu","description":null,"include":null,"notes":null},{"ke ...
#  remoteChecksFailed: 0
#  remoteChecksSuccess: 0
#  remoteEnded: None
#  remoteJobId: None
#  remoteJobId2: None
#  remoteLastStatusCheck: None
#  remoteOutcome: None
#  remoteQueue: skx-dev
#  remoteResultInfo: None
#  remoteStarted: None
#  remoteSubmitRetries: 0
#  remoteSubmitted: None
#  sharedAppCtx: silvia
#  sharedAppCtxAttribs: ['SAC_EXEC_SYSTEM_ID', 'SAC_EXEC_SYSTEM_INPUT_DIR', 'SAC_EXEC_SYSTEM_EXEC_DIR', 'SAC_EXEC_SYSTEM_OUTPUT_DIR']
#  stageAppCorrelationId: None
#  stageAppTransactionId: None
#  status: PENDING
#  subscriptions: []
#  tags: []
#  tapisQueue: tapis.jobq.submit.DefaultQueue
#  tenant: designsafe
#  trackingId: None
#  uuid: 41d6ee21-d6a4-4898-886b-8e99870bf854-007
#  visible: True,
#  'job_start_time': 1770743845.307866,
#  'runJobStatus': 'Finished',
#  'job_description': {'name': 'SilviaApp_OpenSeesMPs3Copy_CommunityData',
#   'appId': 'opensees-mp-s3-clone',
#   'appVersion': '0.0.1',
#   'dynamicExecSystem': False,
#   'execSystemId': 'stampede3',
#   'execSystemExecDir': '${JobWorkingDir}',
#   'execSystemInputDir': '${JobWorkingDir}',
#   'execSystemOutputDir': '${JobWorkingDir}',
#   'dtnSystemInputDir': '!tapis_not_set',
#   'dtnSystemOutputDir': '!tapis_not_set',
#   'execSystemLogicalQueue': 'skx-dev',
#   'archiveSystemId': 'designsafe.storage.default',
#   'archiveSystemDir': '${EffectiveUserId}/tapis-jobs-archive/${JobCreateDate}/${JobUUID}',
#   'archiveOnAppError': True,
#   'isMpi': False,
#   'parameterSet': {'appArgs': [{'name': 'Main Script',
#      'arg': 'Ex1a_verymany.Canti2D.Push.mp.tcl'}],
#    'schedulerOptions': [{'name': 'TACC Allocation', 'arg': '-A DS-HPC1'}],
#    'envVariables': []},
#   'fileInputs': [{'name': 'Input Directory',
#     'sourceUrl': 'tapis://designsafe.storage.community/OpenSees/TrainingMaterial/training-OpenSees-on-DesignSafe/Examples_OpenSees/BasicExamples'}],
#   'fileInputArrays': [],
#   'nodeCount': 1,
#   'coresPerNode': 48,
#   'memoryMB': 192000,
#   'maxMinutes': 6,
#   'subscriptions': [],
#   'tags': []},
#  'JobHistory': None,
#  'JobMetadata': {'id': 86004,
#   'name': 'SilviaApp_OpenSeesMPs3Copy_CommunityData',
#   'owner': 'silvia',
#   'tenant': 'designsafe',
#   'description': 'opensees-mp-s3-clone-0.0.1 submitted by silvia@designsafe',
#   'status': 'FINISHED',
#   'condition': 'NORMAL_COMPLETION',
#   'lastMessage': 'Setting job status to FINISHED.',
#   'created': '2026-02-10T17:18:03.777231Z',
#   'ended': '2026-02-10T17:28:31.078037Z',
#   'lastUpdated': '2026-02-10T17:28:31.078037Z',
#   'uuid': '41d6ee21-d6a4-4898-886b-8e99870bf854-007',
#   'appId': 'opensees-mp-s3-clone',
#   'appVersion': '0.0.1',
#   'archiveOnAppError': True,
#   'archiveMode': 'ALWAYS',
#   'dynamicExecSystem': False,
#   'execSystemId': 'stampede3',
#   'execSystemExecDir': '/scratch/05072/silvia/tapis/41d6ee21-d6a4-4898-886b-8e99870bf854-007',
#   'execSystemInputDir': '/scratch/05072/silvia/tapis/41d6ee21-d6a4-4898-886b-8e99870bf854-007',
#   'execSystemOutputDir': '/scratch/05072/silvia/tapis/41d6ee21-d6a4-4898-886b-8e99870bf854-007',
#   'execSystemLogicalQueue': 'skx-dev',
#   'archiveSystemId': 'designsafe.storage.default',
#   'archiveSystemDir': '/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007',
#   'dtnSystemId': None,
#   'dtnSystemInputDir': None,
#   'dtnSystemOutputDir': None,
#   'nodeCount': 1,
#   'coresPerNode': 48,
#   'memoryMB': 192000,
#   'maxMinutes': 6,
#   'fileInputs': '[{"name": "Input Directory", "notes": "{\\"selectionMode\\":\\"directory\\"}", "envKey": "inputDirectory", "optional": false, "sourceUrl": "tapis://designsafe.storage.community/OpenSees/TrainingMaterial/training-OpenSees-on-DesignSafe/Examples_OpenSees/BasicExamples", "targetPath": "inputDirectory", "description": "Input directory that includes the tcl script as well as any other required files. Example input is in tapis://designsafe.storage.community/app_examples/opensees/OpenSeesMP", "autoMountLocal": true, "srcSharedAppCtx": "", "destSharedAppCtx": "silvia"}]',
#   'parameterSet': '{"appArgs": [{"arg": "OpenSeesMP", "name": "Main Program", "notes": "{\\"isHidden\\":true}", "include": null, "description": null}, {"arg": "Ex1a_verymany.Canti2D.Push.mp.tcl", "name": "Main Script", "notes": "{\\"inputType\\":\\"fileInput\\"}", "include": null, "description": "The filename only of the OpenSees TCL script to execute. This file should reside in the Input Directory specified. To use with test input, use \'freeFieldEffective.tcl\'"}], "logConfig": {"stderrFilename": "tapisjob.out", "stdoutFilename": "tapisjob.out"}, "envVariables": [{"key": "_tapisAppId", "notes": null, "value": "opensees-mp-s3-clone", "include": null, "description": null}, {"key": "_tapisAppVersion", "notes": null, "value": "0.0.1", "include": null, "description": null}, {"key": "_tapisArchiveMode", "notes": null, "value": "ALWAYS", "include": null, "description": null}, {"key": "_tapisArchiveOnAppError", "notes": null, "value": "true", "include": null, "description": null}, {"key": "_tapisArchiveSystemDir", "notes": null, "value": "/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007", "include": null, "description": null}, {"key": "_tapisArchiveSystemId", "notes": null, "value": "designsafe.storage.default", "include": null, "description": null}, {"key": "_tapisCoresPerNode", "notes": null, "value": "48", "include": null, "description": null}, {"key": "_tapisDynamicExecSystem", "notes": null, "value": "false", "include": null, "description": null}, {"key": "_tapisEffectiveUserId", "notes": null, "value": "silvia", "include": null, "description": null}, {"key": "_tapisExecSystemExecDir", "notes": null, "value": "/scratch/05072/silvia/tapis/41d6ee21-d6a4-4898-886b-8e99870bf854-007", "include": null, "description": null}, {"key": "_tapisExecSystemHPCQueue", "notes": null, "value": "skx-dev", "include": null, "description": null}, {"key": "_tapisExecSystemId", "notes": null, "value": "stampede3", "include": null, "description": null}, {"key": "_tapisExecSystemInputDir", "notes": null, "value": "/scratch/05072/silvia/tapis/41d6ee21-d6a4-4898-886b-8e99870bf854-007", "include": null, "description": null}, {"key": "_tapisExecSystemLogicalQueue", "notes": null, "value": "skx-dev", "include": null, "description": null}, {"key": "_tapisExecSystemOutputDir", "notes": null, "value": "/scratch/05072/silvia/tapis/41d6ee21-d6a4-4898-886b-8e99870bf854-007", "include": null, "description": null}, {"key": "_tapisJobCreateDate", "notes": null, "value": "2026-02-10Z", "include": null, "description": null}, {"key": "_tapisJobCreateTime", "notes": null, "value": "17:18:03.777231186Z", "include": null, "description": null}, {"key": "_tapisJobCreateTimestamp", "notes": null, "value": "2026-02-10T17:18:03.777231186Z", "include": null, "description": null}, {"key": "_tapisJobName", "notes": null, "value": "SilviaApp_OpenSeesMPs3Copy_CommunityData", "include": null, "description": null}, {"key": "_tapisJobOwner", "notes": null, "value": "silvia", "include": null, "description": null}, {"key": "_tapisJobUUID", "notes": null, "value": "41d6ee21-d6a4-4898-886b-8e99870bf854-007", "include": null, "description": null}, {"key": "_tapisJobWorkingDir", "notes": null, "value": "/scratch/05072/silvia/tapis/41d6ee21-d6a4-4898-886b-8e99870bf854-007", "include": null, "description": null}, {"key": "_tapisMaxMinutes", "notes": null, "value": "6", "include": null, "description": null}, {"key": "_tapisMemoryMB", "notes": null, "value": "192000", "include": null, "description": null}, {"key": "_tapisNodes", "notes": null, "value": "1", "include": null, "description": null}, {"key": "_tapisStderrFilename", "notes": null, "value": "tapisjob.out", "include": null, "description": null}, {"key": "_tapisStdoutFilename", "notes": null, "value": "tapisjob.out", "include": null, "description": null}, {"key": "_tapisSysBatchScheduler", "notes": null, "value": "SLURM", "include": null, "description": null}, {"key": "_tapisSysHost", "notes": null, "value ...
#   'execSystemConstraints': None,
#   'subscriptions': '[]',
#   'blockedCount': 0,
#   'remoteJobId': '2829310',
#   'remoteJobId2': None,
#   'remoteOutcome': 'FINISHED',
#   'remoteResultInfo': '0:0',
#   'remoteQueue': None,
#   'remoteSubmitted': '2026-02-10T17:19:30.372391Z',
#   'remoteStarted': '2026-02-10T17:19:32.796112Z',
#   'remoteEnded': '2026-02-10T17:19:59.992416Z',
#   'remoteSubmitRetries': 0,
#   'remoteChecksSuccess': 4,
#   'remoteChecksFailed': 0,
#   'remoteLastStatusCheck': '2026-02-10T17:19:59.987813Z',
#   'inputTransactionId': 'cec8fefe-450f-41c0-a76e-6f5f8536e019',
#   'inputCorrelationId': '1d8b6f2a-b0ad-4331-a2ec-d9aaee16f689',
#   'archiveTransactionId': 'cf031822-cd06-40a4-985a-b61626ac8935',
#   'archiveCorrelationId': '80879f3f-0732-414b-988f-89297346329f',
#   'stageAppTransactionId': '3fc56dd0-a620-4b86-ba36-fd3d73161e27',
#   'stageAppCorrelationId': '7d1ec678-9ba8-4641-bc2e-591d00712506',
#   'dtnInputTransactionId': None,
#   'dtnInputCorrelationId': None,
#   'dtnOutputTransactionId': None,
#   'dtnOutputCorrelationId': None,
#   'tapisQueue': 'tapis.jobq.submit.DefaultQueue',
#   'visible': True,
#   'createdby': 'silvia',
#   'createdbyTenant': 'designsafe',
#   'tags': None,
#   'jobType': 'BATCH',
#   'isMpi': False,
#   'mpiCmd': None,
#   'cmdPrefix': None,
#   'sharedAppCtx': 'silvia',
#   'sharedAppCtxAttribs': ['SAC_EXEC_SYSTEM_ID',
#    'SAC_EXEC_SYSTEM_INPUT_DIR',
#    'SAC_EXEC_SYSTEM_EXEC_DIR',
#    'SAC_EXEC_SYSTEM_OUTPUT_DIR'],
#   'trackingId': None,
#   'notes': {'icon': 'OpenSees',
#    'label': 'OpenSeesMP',
#    'helpUrl': 'https://www.designsafe-ci.org/user-guide/tools/simulation/#opensees-user-guide',
#    'category': 'Simulation',
#    'isInteractive': False,
#    'hideNodeCountAndCoresPerNode': False},
#   '_fileInputsSpec': None,
#   '_parameterSetModel': None,
#   'archiveSystemDir_user': '/home/jupyter/MyData/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007',
#   'archiveSystemDir_out': '/home/jupyter/MyData/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007'},
#  'JobFiledata': {'Nfiles': 116,
#   'LocalPath': ['opensees.zip',
#    'tapisjob.env',
#    'tapisjob.out',
#    'tapisjob.sh',
#    'tapisjob_app.sh',
#    'inputDirectory/Ex1.Canti2D.Push.mpi.mod.tacc.py',
#    'inputDirectory/Ex1a.Canti2D.Push.mp.tcl',
#    'inputDirectory/Ex1a.Canti2D.Push.mpi.py',
#    'inputDirectory/Ex1a.Canti2D.Push.mpi4py.py',
#    'inputDirectory/Ex1a.Canti2D.Push.mpi4py.tacc.py',
#    'inputDirectory/Ex1a.Canti2D.Push.py',
#    'inputDirectory/Ex1a.Canti2D.Push.tcl',
#    'inputDirectory/Ex1a_many.Canti2D.Push.mp.tcl',
#    'inputDirectory/Ex1a_verymany.Canti2D.Push.mp.tcl',
#    'inputDirectory/LcolList.out',
#    'inputDirectory/simpleSP.tcl',
#    'inputDirectory/DataTCLmp/DBase_Lcol10.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol100.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol1000.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol1001.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol1002.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol1003.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol1004.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol1005.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol1006.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol1007.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol1008.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol1009.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol101.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol102.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol103.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol104.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol105.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol106.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol107.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol108.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol109.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol11.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol110.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol111.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol112.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol113.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol114.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol115.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol116.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol117.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol118.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol119.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol12.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol120.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol121.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol122.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol123.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol124.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol125.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol126.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol127.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol128.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol129.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol13.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol130.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol131.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol132.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol133.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol134.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol135.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol136.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol137.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol138.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol139.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol14.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol140.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol141.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol142.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol143.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol144.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol145.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol146.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol147.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol148.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol149.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol15.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol150.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol151.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol152.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol153.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol154.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol155.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol156.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol157.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol158.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol159.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol16.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol160.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol161.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol162.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol163.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol164.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol165.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol166.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol167.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol168.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol169.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol17.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol170.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol171.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol172.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol173.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol174.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol175.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol176.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol177.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol178.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol179.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol18.0.out',
#    'inputDirectory/DataTCLmp/DBase_Lcol180.0.out'],
#   'FullPath': ['silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/opensees.zip',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/tapisjob.env',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/tapisjob.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/tapisjob.sh',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/tapisjob_app.sh',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/Ex1.Canti2D.Push.mpi.mod.tacc.py',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/Ex1a.Canti2D.Push.mp.tcl',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/Ex1a.Canti2D.Push.mpi.py',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/Ex1a.Canti2D.Push.mpi4py.py',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/Ex1a.Canti2D.Push.mpi4py.tacc.py',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/Ex1a.Canti2D.Push.py',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/Ex1a.Canti2D.Push.tcl',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/Ex1a_many.Canti2D.Push.mp.tcl',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/Ex1a_verymany.Canti2D.Push.mp.tcl',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/LcolList.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/simpleSP.tcl',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol10.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol100.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol1000.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol1001.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol1002.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol1003.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol1004.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol1005.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol1006.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol1007.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol1008.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol1009.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol101.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol102.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol103.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol104.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol105.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol106.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol107.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol108.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol109.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol11.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol110.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol111.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol112.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol113.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol114.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol115.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol116.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol117.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol118.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol119.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol12.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol120.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol121.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol122.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol123.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol124.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol125.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol126.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol127.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol128.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol129.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol13.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol130.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol131.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol132.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol133.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol134.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol135.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol136.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol137.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol138.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol139.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol14.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol140.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol141.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol142.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol143.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol144.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol145.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol146.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol147.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol148.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol149.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol15.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol150.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol151.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol152.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol153.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol154.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol155.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol156.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol157.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol158.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol159.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol16.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol160.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol161.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol162.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol163.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol164.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol165.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol166.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol167.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol168.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol169.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol17.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol170.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol171.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol172.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol173.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol174.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol175.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol176.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol177.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol178.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol179.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol18.0.out',
#    'silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol180.0.out'],
#   'Items': [
#    group: 819066
#    lastModified: 2026-02-10T17:23:39Z
#    mimeType: application/zip
#    name: opensees.zip
#    nativePermissions: rwxrw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/opensees.zip
#    size: 376
#    type: file
#    url: tapis://designsafe.storage.default/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/opensees.zip,
#
#    group: 819066
#    lastModified: 2026-02-10T17:23:40Z
#    mimeType: None
#    name: tapisjob.env
#    nativePermissions: rw-rw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/tapisjob.env
#    size: 1563
#    type: file
#    url: tapis://designsafe.storage.default/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/tapisjob.env,
#
#    group: 819066
#    lastModified: 2026-02-10T17:23:39Z
#    mimeType: None
#    name: tapisjob.out
#    nativePermissions: rw-rw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/tapisjob.out
#    size: 37803
#    type: file
#    url: tapis://designsafe.storage.default/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/tapisjob.out,
#
#    group: 819066
#    lastModified: 2026-02-10T17:23:40Z
#    mimeType: application/x-shar
#    name: tapisjob.sh
#    nativePermissions: rwxrw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/tapisjob.sh
#    size: 1169
#    type: file
#    url: tapis://designsafe.storage.default/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/tapisjob.sh,
#
#    group: 819066
#    lastModified: 2026-02-10T17:23:40Z
#    mimeType: application/x-shar
#    name: tapisjob_app.sh
#    nativePermissions: rwxrw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/tapisjob_app.sh
#    size: 314
#    type: file
#    url: tapis://designsafe.storage.default/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/tapisjob_app.sh,
#
#    group: 819066
#    lastModified: 2026-02-10T17:23:40Z
#    mimeType: text/plain
#    name: Ex1.Canti2D.Push.mpi.mod.tacc.py
#    nativePermissions: rwxrw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/Ex1.Canti2D.Push.mpi.mod.tacc.py
#    size: 4991
#    type: file
#    url: tapis://designsafe.storage.default/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/Ex1.Canti2D.Push.mpi.mod.tacc.py,
#
#    group: 819066
#    lastModified: 2026-02-10T17:23:40Z
#    mimeType: None
#    name: Ex1a.Canti2D.Push.mp.tcl
#    nativePermissions: rwxrw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/Ex1a.Canti2D.Push.mp.tcl
#    size: 5421
#    type: file
#    url: tapis://designsafe.storage.default/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/Ex1a.Canti2D.Push.mp.tcl,
#
#    group: 819066
#    lastModified: 2026-02-10T17:23:41Z
#    mimeType: text/plain
#    name: Ex1a.Canti2D.Push.mpi.py
#    nativePermissions: rwxrw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/Ex1a.Canti2D.Push.mpi.py
#    size: 4706
#    type: file
#    url: tapis://designsafe.storage.default/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/Ex1a.Canti2D.Push.mpi.py,
#
#    group: 819066
#    lastModified: 2026-02-10T17:23:40Z
#    mimeType: text/plain
#    name: Ex1a.Canti2D.Push.mpi4py.py
#    nativePermissions: rwxrw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/Ex1a.Canti2D.Push.mpi4py.py
#    size: 4779
#    type: file
#    url: tapis://designsafe.storage.default/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/Ex1a.Canti2D.Push.mpi4py.py,
#
#    group: 819066
#    lastModified: 2026-02-10T17:23:41Z
#    mimeType: text/plain
#    name: Ex1a.Canti2D.Push.mpi4py.tacc.py
#    nativePermissions: rwxrw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/Ex1a.Canti2D.Push.mpi4py.tacc.py
#    size: 4805
#    type: file
#    url: tapis://designsafe.storage.default/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/Ex1a.Canti2D.Push.mpi4py.tacc.py,
#
#    group: 819066
#    lastModified: 2026-02-10T17:23:41Z
#    mimeType: text/plain
#    name: Ex1a.Canti2D.Push.py
#    nativePermissions: rwxrw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/Ex1a.Canti2D.Push.py
#    size: 5219
#    type: file
#    url: tapis://designsafe.storage.default/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/Ex1a.Canti2D.Push.py,
#
#    group: 819066
#    lastModified: 2026-02-10T17:23:42Z
#    mimeType: None
#    name: Ex1a.Canti2D.Push.tcl
#    nativePermissions: rwxrw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/Ex1a.Canti2D.Push.tcl
#    size: 4835
#    type: file
#    url: tapis://designsafe.storage.default/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/Ex1a.Canti2D.Push.tcl,
#
#    group: 819066
#    lastModified: 2026-02-10T17:23:41Z
#    mimeType: None
#    name: Ex1a_many.Canti2D.Push.mp.tcl
#    nativePermissions: rwxrw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/Ex1a_many.Canti2D.Push.mp.tcl
#    size: 6320
#    type: file
#    url: tapis://designsafe.storage.default/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/Ex1a_many.Canti2D.Push.mp.tcl,
#
#    group: 819066
#    lastModified: 2026-02-10T17:23:41Z
#    mimeType: None
#    name: Ex1a_verymany.Canti2D.Push.mp.tcl
#    nativePermissions: rwxrw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/Ex1a_verymany.Canti2D.Push.mp.tcl
#    size: 6406
#    type: file
#    url: tapis://designsafe.storage.default/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/Ex1a_verymany.Canti2D.Push.mp.tcl,
#
#    group: 819066
#    lastModified: 2026-02-10T17:23:41Z
#    mimeType: None
#    name: LcolList.out
#    nativePermissions: rw-rw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/LcolList.out
#    size: 5920
#    type: file
#    url: tapis://designsafe.storage.default/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/LcolList.out,
#
#    group: 819066
#    lastModified: 2026-02-10T17:23:41Z
#    mimeType: None
#    name: simpleSP.tcl
#    nativePermissions: rwxrw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/simpleSP.tcl
#    size: 3249
#    type: file
#    url: tapis://designsafe.storage.default/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/simpleSP.tcl,
#
#    group: 819066
#    lastModified: 2026-02-10T17:23:42Z
#    mimeType: None
#    name: DBase_Lcol10.0.out
#    nativePermissions: rw-rw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol10.0.out
#    size: 13215
#    type: file
#    url: tapis://designsafe.storage.default/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol10.0.out,
#
#    group: 819066
#    lastModified: 2026-02-10T17:23:42Z
#    mimeType: None
#    name: DBase_Lcol100.0.out
#    nativePermissions: rw-rw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol100.0.out
#    size: 13990
#    type: file
#    url: tapis://designsafe.storage.default/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol100.0.out,
#
#    group: 819066
#    lastModified: 2026-02-10T17:23:42Z
#    mimeType: None
#    name: DBase_Lcol1000.0.out
#    nativePermissions: rw-rw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol1000.0.out
#    size: 15150
#    type: file
#    url: tapis://designsafe.storage.default/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol1000.0.out,
#
#    group: 819066
#    lastModified: 2026-02-10T17:23:42Z
#    mimeType: None
#    name: DBase_Lcol1001.0.out
#    nativePermissions: rw-rw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol1001.0.out
#    size: 15150
#    type: file
#    url: tapis://designsafe.storage.default/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol1001.0.out,
#
#    group: 819066
#    lastModified: 2026-02-10T17:23:42Z
#    mimeType: None
#    name: DBase_Lcol1002.0.out
#    nativePermissions: rw-rw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol1002.0.out
#    size: 15141
#    type: file
#    url: tapis://designsafe.storage.default/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol1002.0.out,
#
#    group: 819066
#    lastModified: 2026-02-10T17:23:42Z
#    mimeType: None
#    name: DBase_Lcol1003.0.out
#    nativePermissions: rw-rw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol1003.0.out
#    size: 15147
#    type: file
#    url: tapis://designsafe.storage.default/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol1003.0.out,
#
#    group: 819066
#    lastModified: 2026-02-10T17:23:44Z
#    mimeType: None
#    name: DBase_Lcol1004.0.out
#    nativePermissions: rw-rw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol1004.0.out
#    size: 15149
#    type: file
#    url: tapis://designsafe.storage.default/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol1004.0.out,
#
#    group: 819066
#    lastModified: 2026-02-10T17:23:45Z
#    mimeType: None
#    name: DBase_Lcol1005.0.out
#    nativePermissions: rw-rw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol1005.0.out
#    size: 15153
#    type: file
# ...
#    name: DBase_Lcol151.0.out
#    nativePermissions: rw-rw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol151.0.out
#    size: 13993
#    type: file
#    url: tapis://designsafe.storage.default/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol151.0.out,
#
#    group: 819066
#    lastModified: 2026-02-10T17:23:57Z
#    mimeType: None
#    name: DBase_Lcol152.0.out
#    nativePermissions: rw-rw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol152.0.out
#    size: 13978
#    type: file
#    url: tapis://designsafe.storage.default/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol152.0.out,
#
#    group: 819066
#    lastModified: 2026-02-10T17:23:57Z
#    mimeType: None
#    name: DBase_Lcol153.0.out
#    nativePermissions: rw-rw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol153.0.out
#    size: 13988
#    type: file
#    url: tapis://designsafe.storage.default/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol153.0.out,
#
#    group: 819066
#    lastModified: 2026-02-10T17:23:57Z
#    mimeType: None
#    name: DBase_Lcol154.0.out
#    nativePermissions: rw-rw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol154.0.out
#    size: 14008
#    type: file
#    url: tapis://designsafe.storage.default/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol154.0.out,
#
#    group: 819066
#    lastModified: 2026-02-10T17:23:58Z
#    mimeType: None
#    name: DBase_Lcol155.0.out
#    nativePermissions: rw-rw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol155.0.out
#    size: 13988
#    type: file
#    url: tapis://designsafe.storage.default/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol155.0.out,
#
#    group: 819066
#    lastModified: 2026-02-10T17:23:58Z
#    mimeType: None
#    name: DBase_Lcol156.0.out
#    nativePermissions: rw-rw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol156.0.out
#    size: 13986
#    type: file
#    url: tapis://designsafe.storage.default/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol156.0.out,
#
#    group: 819066
#    lastModified: 2026-02-10T17:23:58Z
#    mimeType: None
#    name: DBase_Lcol157.0.out
#    nativePermissions: rw-rw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol157.0.out
#    size: 13986
#    type: file
#    url: tapis://designsafe.storage.default/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol157.0.out,
#
#    group: 819066
#    lastModified: 2026-02-10T17:23:58Z
#    mimeType: None
#    name: DBase_Lcol158.0.out
#    nativePermissions: rw-rw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol158.0.out
#    size: 13992
#    type: file
#    url: tapis://designsafe.storage.default/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol158.0.out,
#
#    group: 819066
#    lastModified: 2026-02-10T17:23:58Z
#    mimeType: None
#    name: DBase_Lcol159.0.out
#    nativePermissions: rw-rw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol159.0.out
#    size: 13995
#    type: file
#    url: tapis://designsafe.storage.default/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol159.0.out,
#
#    group: 819066
#    lastModified: 2026-02-10T17:23:58Z
#    mimeType: None
#    name: DBase_Lcol16.0.out
#    nativePermissions: rw-rw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol16.0.out
#    size: 13582
#    type: file
#    url: tapis://designsafe.storage.default/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol16.0.out,
#
#    group: 819066
#    lastModified: 2026-02-10T17:23:59Z
#    mimeType: None
#    name: DBase_Lcol160.0.out
#    nativePermissions: rw-rw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol160.0.out
#    size: 13994
#    type: file
#    url: tapis://designsafe.storage.default/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol160.0.out,
#
#    group: 819066
#    lastModified: 2026-02-10T17:23:59Z
#    mimeType: None
#    name: DBase_Lcol161.0.out
#    nativePermissions: rw-rw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol161.0.out
#    size: 13999
#    type: file
#    url: tapis://designsafe.storage.default/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol161.0.out,
#
#    group: 819066
#    lastModified: 2026-02-10T17:23:59Z
#    mimeType: None
#    name: DBase_Lcol162.0.out
#    nativePermissions: rw-rw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol162.0.out
#    size: 13994
#    type: file
#    url: tapis://designsafe.storage.default/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol162.0.out,
#
#    group: 819066
#    lastModified: 2026-02-10T17:23:59Z
#    mimeType: None
#    name: DBase_Lcol163.0.out
#    nativePermissions: rw-rw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol163.0.out
#    size: 13992
#    type: file
#    url: tapis://designsafe.storage.default/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol163.0.out,
#
#    group: 819066
#    lastModified: 2026-02-10T17:24:00Z
#    mimeType: None
#    name: DBase_Lcol164.0.out
#    nativePermissions: rw-rw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol164.0.out
#    size: 13996
#    type: file
#    url: tapis://designsafe.storage.default/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol164.0.out,
#
#    group: 819066
#    lastModified: 2026-02-10T17:23:59Z
#    mimeType: None
#    name: DBase_Lcol165.0.out
#    nativePermissions: rw-rw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol165.0.out
#    size: 13988
#    type: file
#    url: tapis://designsafe.storage.default/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol165.0.out,
#
#    group: 819066
#    lastModified: 2026-02-10T17:24:00Z
#    mimeType: None
#    name: DBase_Lcol166.0.out
#    nativePermissions: rw-rw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol166.0.out
#    size: 13989
#    type: file
#    url: tapis://designsafe.storage.default/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol166.0.out,
#
#    group: 819066
#    lastModified: 2026-02-10T17:24:00Z
#    mimeType: None
#    name: DBase_Lcol167.0.out
#    nativePermissions: rw-rw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol167.0.out
#    size: 13989
#    type: file
#    url: tapis://designsafe.storage.default/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol167.0.out,
#
#    group: 819066
#    lastModified: 2026-02-10T17:24:01Z
#    mimeType: None
#    name: DBase_Lcol168.0.out
#    nativePermissions: rw-rw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol168.0.out
#    size: 13991
#    type: file
#    url: tapis://designsafe.storage.default/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol168.0.out,
#
#    group: 819066
#    lastModified: 2026-02-10T17:24:01Z
#    mimeType: None
#    name: DBase_Lcol169.0.out
#    nativePermissions: rw-rw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol169.0.out
#    size: 13992
#    type: file
#    url: tapis://designsafe.storage.default/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol169.0.out,
#
#    group: 819066
#    lastModified: 2026-02-10T17:24:02Z
#    mimeType: None
#    name: DBase_Lcol17.0.out
#    nativePermissions: rw-rw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol17.0.out
#    size: 13664
#    type: file
#    url: tapis://designsafe.storage.default/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol17.0.out,
#
#    group: 819066
#    lastModified: 2026-02-10T17:24:01Z
#    mimeType: None
#    name: DBase_Lcol170.0.out
#    nativePermissions: rw-rw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol170.0.out
#    size: 13980
#    type: file
#    url: tapis://designsafe.storage.default/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol170.0.out,
#
#    group: 819066
#    lastModified: 2026-02-10T17:24:01Z
#    mimeType: None
#    name: DBase_Lcol171.0.out
#    nativePermissions: rw-rw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol171.0.out
#    size: 13997
#    type: file
#    url: tapis://designsafe.storage.default/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol171.0.out,
#
#    group: 819066
#    lastModified: 2026-02-10T17:24:02Z
#    mimeType: None
#    name: DBase_Lcol172.0.out
#    nativePermissions: rw-rw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol172.0.out
#    size: 13996
#    type: file
#    url: tapis://designsafe.storage.default/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol172.0.out,
#
#    group: 819066
#    lastModified: 2026-02-10T17:24:01Z
#    mimeType: None
#    name: DBase_Lcol173.0.out
#    nativePermissions: rw-rw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol173.0.out
#    size: 13994
#    type: file
#    url: tapis://designsafe.storage.default/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol173.0.out,
#
#    group: 819066
#    lastModified: 2026-02-10T17:24:02Z
#    mimeType: None
#    name: DBase_Lcol174.0.out
#    nativePermissions: rw-rw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol174.0.out
#    size: 13981
#    type: file
#    url: tapis://designsafe.storage.default/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol174.0.out,
#
#    group: 819066
#    lastModified: 2026-02-10T17:24:02Z
#    mimeType: None
#    name: DBase_Lcol175.0.out
#    nativePermissions: rw-rw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol175.0.out
#    size: 13993
#    type: file
#    url: tapis://designsafe.storage.default/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol175.0.out,
#
#    group: 819066
#    lastModified: 2026-02-10T17:24:02Z
#    mimeType: None
#    name: DBase_Lcol176.0.out
#    nativePermissions: rw-rw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol176.0.out
#    size: 13994
#    type: file
#    url: tapis://designsafe.storage.default/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol176.0.out,
#
#    group: 819066
#    lastModified: 2026-02-10T17:24:02Z
#    mimeType: None
#    name: DBase_Lcol177.0.out
#    nativePermissions: rw-rw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol177.0.out
#    size: 13993
#    type: file
#    url: tapis://designsafe.storage.default/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol177.0.out,
#
#    group: 819066
#    lastModified: 2026-02-10T17:24:02Z
#    mimeType: None
#    name: DBase_Lcol178.0.out
#    nativePermissions: rw-rw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol178.0.out
#    size: 14000
#    type: file
#    url: tapis://designsafe.storage.default/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol178.0.out,
#
#    group: 819066
#    lastModified: 2026-02-10T17:24:03Z
#    mimeType: None
#    name: DBase_Lcol179.0.out
#    nativePermissions: rw-rw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol179.0.out
#    size: 13996
#    type: file
#    url: tapis://designsafe.storage.default/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol179.0.out,
#
#    group: 819066
#    lastModified: 2026-02-10T17:24:02Z
#    mimeType: None
#    name: DBase_Lcol18.0.out
#    nativePermissions: rw-rw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol18.0.out
#    size: 13793
#    type: file
#    url: tapis://designsafe.storage.default/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol18.0.out,
#
#    group: 819066
#    lastModified: 2026-02-10T17:24:03Z
#    mimeType: None
#    name: DBase_Lcol180.0.out
#    nativePermissions: rw-rw----
#    owner: 843714
#    path: silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol180.0.out
#    size: 13997
#    type: file
#    url: tapis://designsafe.storage.default/silvia/tapis-jobs-archive/2026-02-10Z/41d6ee21-d6a4-4898-886b-8e99870bf854-007/inputDirectory/DataTCLmp/DBase_Lcol180.0.out]},
#  'JobStatusData':
#  condition: NORMAL_COMPLETION
#  status: FINISHED}

# %%
jobstatus = jobReturns['JobStatusData'].__dict__['status']
print('Job Status:',jobstatus)
# Out:
# Job Status: FINISHED
